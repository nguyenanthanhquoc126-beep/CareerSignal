# %%
import pandas as pd

# %%
data=pd.read_csv("/mnt/c/Users/LEGION/CareerSignal/ITViec_jobs.csv")
data
# Out:
#                                    job_id  \
# 0    f4ed3c4e-da33-4404-aa31-fce086c3dc5b
# 1    918e3a81-c1b8-4320-983d-c950f6f4bedb
# 2    238dbb5f-1d0a-444c-96df-773797d4498e
# 3    8202812d-cac4-4f4e-866a-5d1926243ec2
# 4    9368228d-d23a-4361-902f-fa97f2f900db
# ..                                    ...
# 882  122be624-74e8-4faf-9291-b99c3ad20841
# 883  22c08f78-8620-4e56-8abb-9778d1c641ba
# 884  52d59b0c-8a4e-4ca1-96a7-0289fa87b79d
# 885  e81252ca-96d0-44b1-9d63-093ac4eea572
# 886  356ba0ee-be19-4d18-881b-8eb4e9d316bd
#
#                                                   slug  \
# 0    ai-engineer-python-machine-learning-fpt-digita...
# 1    data-engineer-python-sql-power-bi-fpt-digital-...
# 2    analyst-optimization-specialist-python-c-cong-...
# 3     chuyen-vien-an-toan-thong-tin-viettel-group-5108
# 4    application-support-engineer-java-oracle-sql-v...
# ..                                                 ...
# 882  senior-ui-ux-designer-hitachi-digital-services...
# ...

# %%
data.columns
# Out:
# Index(['job_id', 'slug', 'title', 'job_url', 'company_name', 'company_url',
#        'company_logo', 'salary', 'job_category', 'working_model', 'location',
#        'skills', 'benefits', 'label', 'posted_at', 'source_page',
#        'scraped_at'],
#       dtype='str')

# %%
data['company_name']
# Out:
# 0                         FPT Digital
# 1                         FPT Digital
# 2      Công ty cổ phần hàng hải Vsico
# 3                       Viettel Group
# 4                        Vietnamobile
#                     ...
# 882          Hitachi Digital Services
# 883                    Parcel Perform
# 884             Rakus Vietnam Company
# 885                      TPS Software
# 886                              Timo
# Name: company_name, Length: 887, dtype: str

# %%
data[data['job_category']=='Data Engineer'].count()
# Out:
# job_id           31
# slug             31
# title            31
# job_url          31
# company_name     31
# company_url      31
# company_logo     31
# salary           31
# job_category     31
# working_model    31
# location         31
# skills           31
# benefits         31
# label            12
# posted_at        31
# source_page      31
# scraped_at       31
# dtype: int64

# %%
data2=pd.read_csv("/mnt/c/Users/LEGION/CareerSignal/ingestion/topcv_it_jobs.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data2=pd.read_csv("/mnt/c/Users/LEGION/CareerSignal/ingestion/topcv_it_jobs.csv")
#
# File /mnt/c/Users/LEGION/CareerSignal/.venv312/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
data2
# Out:
#        job_id  source_page  position  \
# 0     2247073            1         1
# 1     1778187            1         2
# 2     2228640            1         3
# 3     2220160            1         4
# 4     2250125            1         5
# ...       ...          ...       ...
# 2093  1556013           64        46
# 2094  2181160           64        47
# 2095  2216337           64        48
# 2096  2214458           64        49
# 2097  2035701           64        50
#
#                                             tracking_id         box_type  \
# 0     wqDiWOa2JDMU3lNbyNmOqGREB44dR0ktgdXa0N5D_17850...  BoxSearchResult
# 1     wqDiWOa2JDMU3lNbyNmOqGREB44dR0ktgdXa0N5D_17850...  BoxSearchResult
# 2     wqDiWOa2JDMU3lNbyNmOqGREB44dR0ktgdXa0N5D_17850...  BoxSearchResult
# 3     wqDiWOa2JDMU3lNbyNmOqGREB44dR0ktgdXa0N5D_17850...  BoxSearchResult
# 4     wqDiWOa2JDMU3lNbyNmOqGREB44dR0ktgdXa0N5D_17850...  BoxSearchResult
# ...

# %%
data2.columns
data.columns
# Out:
# Index(['job_id', 'slug', 'title', 'job_url', 'company_name', 'company_url',
#        'company_logo', 'salary', 'job_category', 'working_model', 'location',
#        'skills', 'benefits', 'label', 'posted_at', 'source_page',
#        'scraped_at'],
#       dtype='str')

# %%
data[data['label'].notnull()]
# Out:
#                                    job_id  \
# 0    f4ed3c4e-da33-4404-aa31-fce086c3dc5b
# 1    918e3a81-c1b8-4320-983d-c950f6f4bedb
# 2    238dbb5f-1d0a-444c-96df-773797d4498e
# 3    8202812d-cac4-4f4e-866a-5d1926243ec2
# 4    9368228d-d23a-4361-902f-fa97f2f900db
# ..                                    ...
# 319  b7e9d997-6b7b-42a2-985a-0108d9dace48
# 320  fb758faa-8a3e-4ed4-8edc-1ff3f98a069e
# 321  1803e3e5-7aeb-4bc7-a14e-d6cbcb3da529
# 322  3fd60960-b2f0-4e20-92ea-0380fc2b15f1
# 705  995c8e30-2919-44e8-bfd6-5f7a1355c2a9
#
#                                                   slug  \
# 0    ai-engineer-python-machine-learning-fpt-digita...
# 1    data-engineer-python-sql-power-bi-fpt-digital-...
# 2    analyst-optimization-specialist-python-c-cong-...
# 3     chuyen-vien-an-toan-thong-tin-viettel-group-5108
# 4    application-support-engineer-java-oracle-sql-v...
# ..                                                 ...
# 319  it-manager-azure-cloud-networking-cong-ty-tnhh...
# ...

# %%
data[data['benefits'] !='[]']['benefits']
# Out:
# 3      ["Dẫn đầu thị trường", "Cơ hội thử thách và ph...
# 6      ["Very competitive remuneration package", "Bui...
# 7      ["Very competitive remuneration package", "Bui...
# 8      ["Môi trường làm việc đa quốc gia", "Cơ hội th...
# 9      ["Top-ranking of corporate value increase rate...
#                              ...
# 755    ["Year-end Bonus & Performance review twice a ...
# 761    ["Very competitive remuneration package", "Bui...
# 781    ["Stock options", "Vietnam labor law contract ...
# 783    ["Salary up to $2500", "13th month of salary",...
# 786    ["Very attractive salary package and Bonus", "...
# Name: benefits, Length: 223, dtype: str

# %%
data2['job_id'].sort_values(ascending=False)
# Out:
# 516     2250531
# 520     2250486
# 83      2250430
# 9       2250378
# 522     2250372
#          ...
# 1681     639349
# 1979     575992
# 1084     546494
# 1890     500122
# 1887     293807
# Name: job_id, Length: 2098, dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [job_id, slug, title, job_url, company_name, company_url, company_logo, salary, job_category, working_model, location, skills, benefits, label, posted_at, source_page, scraped_at]
# Index: []

# %%
data2[['posted_time','updated_time','scraped_at']]
# Out:
#              posted_time            updated_time           scraped_at
# 0      Đăng 3 ngày trước     Cập nhật 1 giây tới  2026-07-26T17:40:23
# 1      Đăng 3 ngày trước   Cập nhật 3 giây trước  2026-07-26T17:40:23
# 2      Đăng 3 ngày trước   Cập nhật 1 phút trước  2026-07-26T17:40:23
# 3      Đăng 1 tuần trước   Cập nhật 1 phút trước  2026-07-26T17:40:23
# 4      Đăng 1 ngày trước   Cập nhật 4 phút trước  2026-07-26T17:40:23
# ...                  ...                     ...                  ...
# 2093  Đăng 1 tháng trước  Cập nhật 1 tháng trước  2026-07-26T17:40:23
# 2094  Đăng 1 tháng trước  Cập nhật 1 tháng trước  2026-07-26T17:40:23
# 2095  Đăng 1 tháng trước  Cập nhật 1 tháng trước  2026-07-26T17:40:23
# 2096  Đăng 1 tháng trước  Cập nhật 1 tháng trước  2026-07-26T17:40:23
# 2097  Đăng 1 tháng trước  Cập nhật 1 tháng trước  2026-07-26T17:40:23
#
# [2098 rows x 3 columns]

# %%
dataITViec=pd.read_csv("/mnt/c/Users/LEGION/CareerSignal/ITViec_jobs.csv")
datatopcv=pd.read_csv("/mnt/c/Users/LEGION/CareerSignal/topcv_it_jobs.csv")

# %%
dataITViec
# Out:
#                                    job_id  \
# 0    f4ed3c4e-da33-4404-aa31-fce086c3dc5b
# 1    918e3a81-c1b8-4320-983d-c950f6f4bedb
# 2    238dbb5f-1d0a-444c-96df-773797d4498e
# 3    8202812d-cac4-4f4e-866a-5d1926243ec2
# 4    9368228d-d23a-4361-902f-fa97f2f900db
# ..                                    ...
# 882  122be624-74e8-4faf-9291-b99c3ad20841
# 883  22c08f78-8620-4e56-8abb-9778d1c641ba
# 884  52d59b0c-8a4e-4ca1-96a7-0289fa87b79d
# 885  e81252ca-96d0-44b1-9d63-093ac4eea572
# 886  356ba0ee-be19-4d18-881b-8eb4e9d316bd
#
#                                                   slug  \
# 0    ai-engineer-python-machine-learning-fpt-digita...
# 1    data-engineer-python-sql-power-bi-fpt-digital-...
# 2    analyst-optimization-specialist-python-c-cong-...
# 3     chuyen-vien-an-toan-thong-tin-viettel-group-5108
# 4    application-support-engineer-java-oracle-sql-v...
# ..                                                 ...
# 882  senior-ui-ux-designer-hitachi-digital-services...
# ...
